# %%
import scipy 
import numpy as np 
# import matplotlib.pyplot as plt
import mat73

# %%
filename = r"C:\Users\meg_r\Desktop\session_31__set_9.mat"
data_dict = mat73.loadmat(filename)
# Out:
# ERROR:root:ERROR: MATLAB type not supported: string, (uint32)
# ERROR:root:ERROR: MATLAB type not supported: string, (uint32)
# ERROR:root:ERROR: MATLAB type not supported: string, (uint32)
# ERROR:root:ERROR: MATLAB type not supported: string, (uint32)

# %%
import h5py
with h5py.File(filename, "r") as h5f:
    print(h5f.keys())
    print(h5f['p'].keys())
    print(h5f["p/downsample"][:])
# Out:
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'm', 'p']>
# <KeysViewHDF5 ['Fs', 'Fsguard', 'aafa', 'aafb', 'bounds_bl', 'bounds_epo', 'bounds_est', 'bounds_rm', 'doCAR', 'downsample', 'interpfirst', 'locs', 'locs_stim', 'removefirst']>
# [[5.]]
